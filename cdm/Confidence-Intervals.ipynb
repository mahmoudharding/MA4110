# %% [markdown]
# # Confidence Intervals

# %%
from datascience import *
import numpy as np
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Employment Data from the City of Durham
#
# The following code will read in a table that contains a random sample of 200 workers from the City of Durham.
#
# **Question 1.** Run the cell below to load as a table.

# %%
# Question 1
sample_employees = Table().read_table('durham_sample.csv')
sample_employees
# Out:
# 200

# %% [markdown]
# The cell below will generate a histogram that shows the distribution of salaries from the sample.
#
# **Question 2.** Run the cell below to display the histogram.

# %%
# Question 2
sample_employees.hist('SALARY', unit = "Dollars")

# %% [markdown]
# The `percentile()` function returns returns the *p*th percentile of the input array (the value that is at least as great as *p*% of the values in the array)
#
# **Question 3.** Use the `percentile()` function to find the salary that is greater than or equal to 50% of the employees in the sample.

# %%
# Question 3
percentile(50, sample_employees.column('SALARY'))
# Out:
# 40048.84

# %% [markdown]
# **Question 4.** What is the median salary from the sample.

# %%
# Question 4
# Out:
# 40103.96

# %% [markdown]
# **Question 5.** Why do you think the value from Question 3 is different fromt he value in Question 4.

# %%
# Question 5
# Out:
# 40103.96

# %% [markdown]
# ## The Goal
#
# We'd like to know what the median salary is for **all** workers from the City of Durham, not just from our sample of 200 workers. This particular sample may vary depending on which 200 workers are selected. We will resample our sample from the population to determine a measure of how variable the median might be, and then build an interval that we feel the true median of the population should be between.
#
# ### Resampling
#
# **Question 6.** Create an array named `medians` that contains the median of 1000 samples (`with_replacement`) of the `sample_employees` table.

# %%
# Question 6

# %% [markdown]
# **Question 7.** What is the median of the `medians` array.

# %%
# Question 7
# Out:
# 40159.08

# %% [markdown]
# ### The Population
#
# The following code will read in a table that contains all workers from the City of Durham and generate a histogram that shows the distribution of salaries.
#
# **Question 8.** Run the cell below to read the table and display the histogram.

# %%
# Question 8
population_employees = Table().read_table('city_of_durham.csv')

my_bins = np.arange(0, 175000, 15000)
population_employees.hist('SALARY', bins = my_bins, unit = 'Dollars')

# %% [markdown]
# ### How did we do?
#
# Normally we wouldn't have access to the population data (if we did, there'd be no reason to estimate the median of the population, we could just calculate it). But, here we do have it.
#
# **Question 9.** Let's see if the true population median is in our 95% confidence interval.

# %%
# Question 9
lower_bound = 
upper_bound =
# Out:
# (37842.81, 43702.854999999996)

# %% [markdown]
# **Question 10.** Let's visualize our emperical distribution using a histogram with the 95% confidence interval overlayed.

# %%
# Question 10
Table().with_column('Resampled Medians', medians).hist()
plt.plot([lower_bound, upper_bound], [0, 0], color = 'gold', lw = 10);
